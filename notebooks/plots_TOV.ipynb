# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import data

# %%
root = '../sim_data/tov_ET'

# %%
it, t, rho_max = np.loadtxt(f'{root}/hydrobase-rho.maximum.asc', unpack = True)
it, t, press_max = np.loadtxt(f'{root}/hydrobase-press.maximum.asc', unpack = True)

# %%
plt.plot(t, rho_max/rho_max[0])

# %%
plt.plot(t, 100*rho_max**2)
plt.plot(t, press_max, '--')

# %%
it, t, lapse_max = np.loadtxt(f'{root}/admbase-lapse.maximum.asc', unpack = True)
plt.plot(t, lapse_max)

# %%
def get_1d_data(file):
    _, t, rho_max = np.loadtxt(file, unpack = True)
    return t, rho_max

# %%
file1 = '../sim_data/tov_ET/hydrobase-rho.maximum.asc'
t1, rho1 = get_1d_data(file1)

# %%
plt.plot(t1, rho1)
