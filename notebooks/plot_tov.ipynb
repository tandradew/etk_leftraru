# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls
# Out:
# README.md                etk_install.sh           leftraru_config
# Untitled.ipynb           grhydro-dens.maximum.asc test_parfiles

# %%
a, b, c = np.loadtxt('grhydro-dens.maximum.asc', unpack = True)

# %%
plt.plot(b, c)
